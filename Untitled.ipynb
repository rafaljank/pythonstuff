# %%
import requests as rq
import re
import pandas as pd
from datetime import datetime as dt
import seaborn as sns
# %matplotlib inline

# %%
strona=rq.get('https://www.xtb.com/pl/aktualno%C5%9Bci?page=1').text

# %%
for i in range(1,100):
    strona=rq.get('https://www.xtb.com/pl/aktualno%C5%9Bci?page='+__builtins__.str(i)).text
    if (i<64):
        match=re.search('VOLX.*? dla pozycji .*?\d+',strona,re.MULTILINE)
    else:
        match=re.search('VOLX.*? swap points .*?\d+',strona,re.MULTILINE)
    if(match):
        print('https://www.xtb.com/pl/aktualno%C5%9Bci?page='+__builtins__.str(i))
        print(match.group(0))
# Out:
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=1
# VOLX+, VOLX.., VOLX., VOLX -150 pkt swapowych dla pozycji długiej; 150
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=7
# VOLX+, VOLX.., VOLX., VOLX -135 pkt swapowych dla pozycji długiej; 135
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=11
# VOLX+, VOLX.., VOLX., VOLX -39 pkt swapowych dla pozycji długiej; 39
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=16
# VOLX+, VOLX.., VOLX., VOLX -84 pkt swapowych dla pozycji długiej; 84
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=20
# VOLX+, VOLX.., VOLX., VOLX -110 pkt swapowych dla pozycji długiej; 110
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=23
# VOLX+, VOLX.., VOLX., VOLX 4 pkt swapowych dla pozycji długiej; -4
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=28
# VOLX+, VOLX.., VOLX., VOLX -180 pkt swapowych dla pozycji długiej; 180
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=32
# VOLX, VOLX., VOLX.., VOLX+ -127 pkt swapowych dla pozycji długiej; 127
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=34
# VOLX, VOLX., VOLX.., VOLX+ -178 pkt swapowych dla pozycji długiej; 178
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=38
# VOLX, VOLX., VOLX.., VOLX+ -205 pkt swapowych dla pozycji długiej; 205
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=42
# VOLX, VOLX., VOLX.., VOLX+ -61 pkt swapowych dla pozycji długiej; 61
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=45
# VOLX, VOLX., VOLX.., VOLX+ -113 pkt swapowych dla pozycji długiej; 113
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=48
# VOLX, VOLX., VOLX.., VOLX+ -252 pkt swapowych dla pozycji długiej; 252
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=51
# VOLX, VOLX., VOLX.., VOLX+ -249 pkt swapowych dla pozycji długiej; 249
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=53
# VOLX, VOLX., VOLX.., VOLX+ -198 pkt swapowych dla pozycji długiej; 198
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=57
# VOLX, VOLX., VOLX.. -35 pkt swapowych dla pozycji długiej; 35
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=61
# VOLX, VOLX., VOLX.. -235 pkt swapowych dla pozycji długiej; 235
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=64
# VOLX, -180 swap points for long position; 180
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=69
# VOLX, -100 swap points for long position; 100
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=73
# VOLX, -6 swap points for long position; 6
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=76
# VOLX,&nbsp;55 swap points for long position; -55
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=79
# VOLX, 25 swap points for long position; -25
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=82
# VOLX, -70 swap points for long position; 70
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=90
# VOLX, 110 swap points for long position;&nbsp;-110
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=94
# VOLX, -89 swap points for long position; 89

# %%
swaps=pd.DataFrame(columns=["data",'swap_points_for_short'])
swaps['swap_points_for_short']=[150,135,39,84,110,-4,180,127,178,205,61,113,252,249,198,35,235,180,100,6,-55,-25,70,47,-110,89]
swaps['data']=['20170912','20170809','20170706','20170607','20170508','20170406',
              '20170307','20170202','20170105','20161208','20161108',
               '20161011','20160908','20160810','20160713','20160614','20160511','20160406','20160302','20160203'
              ,'20160107','20151210','20151110','20151008','20150909','20150807']
swaps['Date']=swaps['data'].apply(lambda x: dt.strptime(x,'%Y%m%d'))
swaps.drop('data',axis=1)
# Out:
#     swap_points_for_short       Date
# 0                     150 2017-09-12
# 1                     135 2017-08-09
# 2                      39 2017-07-06
# 3                      84 2017-06-07
# 4                     110 2017-05-08
# 5                      -4 2017-04-06
# 6                     180 2017-03-07
# 7                     127 2017-02-02
# 8                     178 2017-01-05
# 9                     205 2016-12-08
# 10                     61 2016-11-08
# 11                    113 2016-10-11
# 12                    252 2016-09-08
# 13                    249 2016-08-10
# 14                    198 2016-07-13
# 15                     35 2016-06-14
# 16                    235 2016-05-11
# 17                    180 2016-04-06
# 18                    100 2016-03-02
# 19                      6 2016-02-03
# 20                    -55 2016-01-07
# 21                    -25 2015-12-10
# 22                     70 2015-11-10
# 23                     47 2015-10-08
# 24                   -110 2015-09-09
# 25                     89 2015-08-07

# %%
#swaps[(swaps['Date']>dt.strptime('20160830','%Y%m%d')) & (swaps['Date']<dt.strptime('20170130','%Y%m%d'))]['swap_points_for_short'].sum()
def sumswaps(begin,end):
    try:
        t1=dt.strptime(begin,'%Y%m%d')
    except ValueError:
        print('Incorrect begin date')
        return -1000000;
    try:
        t2=dt.strptime(end,'%Y%m%d')
    except ValueError:
        print('Incorrect end date')
        return -1000000;        
    return swaps[(swaps['Date']>t1) & (swaps['Date']<t2)]['swap_points_for_short'].sum()



print(sumswaps('20160830','20170330'))
# Out:
# 1116

# %%
vixdata=pd.read_csv('http://www.cboe.com/publish/scheduledtask/mktdata/datahouse/vixcurrent.csv',skiprows=1)
vixdata['Date']=vixdata['Date'].apply(lambda x:dt.strptime(x,'%m/%d/%Y'))
vixdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3450 entries, 0 to 3449
# Data columns (total 5 columns):
# Date         3450 non-null datetime64[ns]
# VIX Open     3450 non-null float64
# VIX High     3450 non-null float64
# VIX Low      3450 non-null float64
# VIX Close    3450 non-null float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 134.8 KB

# %%
vixdata.hist(column='VIX Close',bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000F80A3D9B0>]], dtype=object)

# %%
lbegin=dt.strptime('20160830','%Y%m%d')

print(vixdata[vixdata['Date']==lbegin])
# Out:
#            Date  VIX Open  VIX High  VIX Low  VIX Close
# 3187 2016-08-30     12.94      13.6     12.7      13.12

# %%
def priceindayrange(day,price):
    try:
        lday=dt.strptime(day,'%Y%m%d')
    except ValueError:
        print('Incorrect date')
        return -1000000
    lmax=float(vixdata[vixdata['Date']==lday]['VIX High'])
    lmin=float(vixdata[vixdata['Date']==lday]['VIX Low'])
    if (price>=lmin) & (price<=lmax):
        return True
    return False

print(priceindayrange('20160830',16))
# Out:
# False

# %%
def trade_result(begin,end,direction='short',openprice=None,closeprice=None):
    result=0
    try:
        lbegin=dt.strptime(begin,'%Y%m%d')
    except ValueError:
        print('Incorrect begin date')
        return -1000000
    try:
        lend=dt.strptime(end,'%Y%m%d')       
    except ValueError:
        print('Incorrect end date')
        return -1000000
    if not openprice:
        lopenprice=float(vixdata[vixdata['Date']==lbegin]['VIX Close'])
    elif priceindayrange(begin,openprice):
        lopenprice=openprice
    else:
        print ('Open price not in day renge')
        return -1000000
    if not closeprice:
        lcloseprice=float(vixdata[vixdata['Date']==lend]['VIX Close'])
    elif priceindayrange(end,closeprice):
        lcloseprice=closeprice  
    else:
        print ('Clse price not in day renge')
        return -1000000        
    if direction=='short':
        result=lopenprice-lcloseprice+sumswaps(begin,end)
    else:
        result=-lopenprice+lcloseprice-sumswaps(begin,end)
    return result

trade_result(begin='20160830',end='20170330')
# Out:
# 1117.58

# %%
for i in range(1,70):
    strona=rq.get('https://www.xtb.com/pl/aktualno%C5%9Bci?page='+__builtins__.str(i)).text
    lista=strona.split('VOLX..')
    if(len(lista)>1):
        for j in range(0,len(lista)):
            lan1=lista[j].find('swapowych dla pozycji')
            if (lan1>0):
                            print('https://www.xtb.com/pl/aktualno%C5%9Bci?page='+__builtins__.str(i))
                            print (lista[j][:110])
# Out:
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=1
# , VOLX., VOLX -135 pkt swapowych dla pozycji długiej; 135 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=2
# , WHEAT, WHEAT+, WHEAT., WHEAT..</p>
#
# <p>Z powodu świąt narodowych, handel na następujących instrumentach bę
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=5
# <!DOCTYPE html>
# <html lang="pl" >
#
#     <head xmlns="http://www.w3.org/1999/xhtml" prefix="og: http://ogp.me/ns
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=5
# , VOLX., VOLX -39 pkt swapowych dla pozycji długiej; 39 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>XT
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=6
#  handel do 17:30</p>
#
# <p>GOLD, GOLDs, GOLDs+, GOLDs., XAUUSD.., SILVER, SILVERs, SILVERs+, SILVERs., XAGUSD.
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=10
# , VOLX., VOLX -84 pkt swapowych dla pozycji długiej; 84 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>XT
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=10
#  powinien być wyższy.</p>
#
# <p>Dokładna wielkość bazy znana będzie w momencie zamknięcia handlu i zostanie po
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=10
# , VOLX+</p>
#
# <p>08.06 &ndash; Czwartek &ndash; US100, US.100, US.100+, US.100., US.100.., US30, US.30, US.30
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=11
# , VOLX+ - handel do godziny 17:30</p>
#
# <p>OILs, OILs., OILs.., OILs+ &ndash; handel do godziny 19.30</p>
#
#
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=14
# , VOLX., VOLX -110 pkt swapowych dla pozycji długiej; 110 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=17
# , WHEAT, WHEAT+, WHEAT., WHEAT... Dlatego też klienci posiadający otwarte pozycje zostaną w zależności od zajm
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=17
# , VOLX., VOLX 4 pkt swapowych dla pozycji długiej; -4 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>&nbs
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=17
# , WHEAT, WHEAT+, WHEAT., WHEAT.. powinien być wyższy.</p>
#
# <p>Dokładna wielkość bazy znana będzie w momencie
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=18
# , VOLX+</p>
#
# <p>&nbsp;</p>
#
# <p>Z powodu świąt narodowych handel na następujących instrumentach będzie odwo
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=19
# , VOLX+ &nbsp;- &nbsp;15:35 - 22:15</p>
#
# <p>OIL.WTI, OIL.WTI., OIL.WTI.., OIL.WTI+ - &nbsp;02:05 - 23:00</p>
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=21
#  &ndash; 14:35 &ndash; 21:15</p>
#
# <p>OIL.WTI, OIL.WTI., OIL.WTI+, OIL.WTI.. &ndash; 01:05 &ndash; 22:00</p>
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=22
# . Dlatego też klienci posiadający otwarte pozycje zostaną w zależności od zajmowanej pozycji, uznani bądź obci
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=22
# , VOLX., VOLX -180 pkt swapowych dla pozycji długiej; 180 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=22
# , VOLX+</p>
#
# <p>09.03 &ndash; Czwartek &ndash; US30, US.30, US.30., US.30.., US.30+, US100, US.100, US.100.,
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=24
# , VOLX+&nbsp;&ndash; handel do 17:30</p>
#
# <p>&nbsp;</p>
#
# <p>Dywidendy Equity CFD (płatne w got&oacute;wce)
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=26
# , VOLX+ -127 pkt swapowych dla pozycji długiej; 127 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>- COCO
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=28
# <!DOCTYPE html>
# <html lang="pl" >
#
#     <head xmlns="http://www.w3.org/1999/xhtml" prefix="og: http://ogp.me/ns
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=28
# , VOLX+ -178 pkt swapowych dla pozycji długiej; 178 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>XTB</p
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=29
# , VOLX+</p>
#
# <p>Informacja o świętach zawarta jest w newsie Święta oraz Nowy Rok w XTB</p>
#
# <p>Dywidendy E
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=30
# , VOLX+, OIL, OILs, OILs., OILs.., OILs+, OIL.WTI, OIL.WTI., OIL.WTI.., OIL.WTI+, CORN, CORN., CORN.., CORN+,
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=30
# , VOLX+, OIL, OILs, OILs., OILs.., OILs+, OIL.WTI, OIL.WTI., OIL.WTI.., OIL.WTI+, CORN, CORN., CORN.., CORN+,
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=32
# , VOLX+, SOYBEAN, SOYBEAN., SOYBEAN.., SOYBEAN+ i EMISS, EMISS., EMISS.., EMISS+. Dlatego też klienci posiadaj
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=32
# , VOLX+ -205 pkt swapowych dla pozycji długiej; 205 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>- SOYB
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=32
# , VOLX+ powinien być wyższy, a pozostałych instrument&oacute;w niższy o określone wartości.</p>
#
# <p>Dokładna
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=34
# <!DOCTYPE html>
# <html lang="pl" >
#
#     <head xmlns="http://www.w3.org/1999/xhtml" prefix="og: http://ogp.me/ns
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=34
# , VOLX+ handel do 19:15</p>
#
# <p>GOLD, GOLDs, GOLDs., GOLDs+, XAUUSD.., SILVER, SILVERs, SILVERs., SILVERs+,
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=36
# , VOLX+ -61 pkt swapowych dla pozycji długiej; 61 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>XTB</p><
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=37
# , VOLX+ -&nbsp;14:35 - 21:15</p>
#
# <p>BRAComp, BRAComp., BRAComp.., BRAComp+ -&nbsp;12:05 - 21:10</p>
#
# <p>U
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=39
# , VOLX+ -113 pkt swapowych dla pozycji długiej; 113 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>XTB</p
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=39
# , VOLX+ powinien być wyższy o określone wartości.</p>
#
# <p>Dokładna wielkość bazy znana będzie w momencie zam
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=42
# , VOLX+, RUS50, RUS50., RUS50.., RUS50+ i SUGAR, SUGARs, SUGARs., SUGARs.., SUGARs+. Dlatego też klienci posia
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=42
# , VOLX+ -252 pkt swapowych dla pozycji długiej; 252 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>- RUS5
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=42
# , VOLX+ oraz SUGAR, SUGARs, SUGARs., SUGARs.., SUGARs+ powinien być wyższy, a pozostałych instrument&oacute;w
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=45
# , VOLX+. Dlatego też klienci posiadający otwarte pozycje zostali w zależności od zajmowanej pozycji, uznani bą
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=45
# , VOLX+ -249 pkt swapowych dla pozycji długiej; 249 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>XTB</p
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=45
# , VOLX+. Dlatego też klienci posiadający otwarte pozycje zostaną w zależności od zajmowanej pozycji, uznani bą
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=45
# , VOLX+ -249 pkt swapowych dla pozycji długiej; 249 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>XTB</p
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=47
# <!DOCTYPE html>
# <html lang="pl" >
#
#     <head xmlns="http://www.w3.org/1999/xhtml" prefix="og: http://ogp.me/ns
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=47
# , VOLX+ -198 pkt swapowych dla pozycji długiej; 198 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>- OIL.
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=51
# <!DOCTYPE html>
# <html lang="pl" >
#
#     <head xmlns="http://www.w3.org/1999/xhtml" prefix="og: http://ogp.me/ns
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=51
#  -35 pkt swapowych dla pozycji długiej; 35 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>- BRAComp, BRAC
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=51
# </p>
#
# <p>15.06 &ndash; Środa &ndash; AUS200, AUS200., AUS200.., MEXComp, MEXComp., MEXComp.., OIL.WTI, OIL.W
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=53
#  ,UK100, UK.100, UK.100., UK.100.., CORN, CORN., CORN.., SOYBEAN, SOYBEAN., SOYBEAN.., WHEAT, WHEAT., WHEAT..,
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=55
#  -235 pkt swapowych dla pozycji długiej; 235 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>- OIL.WTI, OI
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=58
# <!DOCTYPE html>
# <html lang="pl" >
#
#     <head xmlns="http://www.w3.org/1999/xhtml" prefix="og: http://ogp.me/ns
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=58
#  -180 pkt swapowych dla pozycji długiej; 180 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>XTB</p>
#
# <p
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=60
# <!DOCTYPE html>
# <html lang="pl" >
#
#     <head xmlns="http://www.w3.org/1999/xhtml" prefix="og: http://ogp.me/ns
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=60
#  &nbsp;- &nbsp;15:35 - 22:15</p>
#
# <p>OIL.WTI, OIL.WTI., OIL.WTI.. - &nbsp;02:05 - 23:00</p>
#
# <p>MEXComp, M
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=61
# , EMISS, EMISS., EMISS.., TNOTE, TNOTE., TNOTE..</p>
#
# <p>OILs, OILs., OILs.., OIL.WTI, OIL.WTI., OIL.WTI..,
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=62
#  &ndash; 14:35 &ndash; 21:15</p>
#
# <p>OIL.WTI, OIL.WTI., OIL.WTI.. &ndash; 01:05 &ndash; 22:00</p>
#
# <p>MEXC
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=63
# <!DOCTYPE html>
# <html lang="pl" >
#
#     <head xmlns="http://www.w3.org/1999/xhtml" prefix="og: http://ogp.me/ns
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=63
#  -100 pkt swapowych dla pozycji długiej; 100 pkt swapowych dla pozycji kr&oacute;tkiej</p>
#
# <p>- BUND10Y, BU

# %%
lista[3]
# Out:
# ', VOLX.., VOLX., VOLX -135 pkt swapowych dla pozycji długiej; 135 pkt swapowych dla pozycji kr&oacute;tkiej</p>\r\n\r\n<p>- COFFEE, COFFEE+, COFFEE.., COFFEE. -350 pkt swapowych dla pozycji długiej; 350 pkt swapowych dla pozycji kr&oacute;tkiej</p>\r\n\r\n<p>- WHEAT.., WHEAT+, WHEAT., WHEAT -2725 pkt swapowych dla pozycji długiej; 2725 pkt swapowych dla pozycji kr&oacute;tkiej</p>\r\n\r\n<p>XTB</p></div>\n        </div>\n        <div class="panel-footer clearfix">\n            <a href="#" class="pull-right read-more js-read-more">\n                więcej aktualności\n                <i class="fa fa-chevron-down"></i>\n            </a>\n            <a href="#" class="pull-right read-more js-read-more">\n                ukryj\n                <i class="fa fa-chevron-up"></i>\n            </a>\n        </div>\n    </div>\n                                                        <div class="panel panel-default" id="rollover-on-coffee-coffee-coffee-coffee-volx-volx-volx-volx-wheat-wheat-wheat-wheat">\n            <div class="panel-heading">\n            <p>14:53</p>\n            <h2 class="panel-header">\n                <a href="#" class="js-read-more">Rolowanie COFFEE, COFFEE+, COFFEE., COFFEE.., VOLX, '

# %%
for i in range(1,70):
    print('https://www.xtb.com/pl/aktualno%C5%9Bci?page='+__builtins__.str(i))
# Out:
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=1
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=2
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=3
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=4
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=5
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=6
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=7
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=8
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=9
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=10
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=11
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=12
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=13
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=14
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=15
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=16
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=17
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=18
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=19
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=20
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=21
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=22
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=23
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=24
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=25
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=26
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=27
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=28
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=29
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=30
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=31
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=32
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=33
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=34
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=35
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=36
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=37
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=38
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=39
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=40
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=41
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=42
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=43
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=44
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=45
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=46
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=47
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=48
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=49
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=50
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=51
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=52
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=53
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=54
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=55
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=56
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=57
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=58
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=59
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=60
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=61
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=62
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=63
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=64
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=65
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=66
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=67
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=68
# https://www.xtb.com/pl/aktualno%C5%9Bci?page=69

# %%
"a"+"b"
# Out:
# 'ab'
